# %%
# %matplotlib inline 

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_excel('data.xls')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19056 entries, 0 to 19055
# Data columns (total 23 columns):
# ID Number                                 19056 non-null int64
# Tipología Anf.                            19056 non-null object
# Tipo de Provincia                         12385 non-null object
# Rango Provincia                           12385 non-null object
# Provincia                                 18936 non-null object
# Pais Moderno                              19055 non-null object
# GIS LH                                    19056 non-null int64
# Tipo de Asentamiento                      19056 non-null object
# Datación Pecios                           234 non-null object
# LH                                        18959 non-null object
# LHE                                       18904 non-null object
# LHE2                                      6710 non-null object
# Cronología inicial Campamento (Fase 1)    3438 non-null object
# Tipo de Campamento (1a Fase)              1686 non-null object
# Cronología final Campamento (Fase 1)      1686 non-null object
# Cronología inicial Campamento (Fase 2)    1686 non-null object
# Tipo de Campamento (2a Fase)              1686 non-null object
# Unidades militares                        2667 non-null object
# Número de soldados                        2631 non-null object
# Tipo de Campamento                        1763 non-null object
# Cronología final Campamento (Fase 2)      3434 non-null object
# Lugar Prod/Lugar Hallago                  19056 non-null int64
# Datación                                  3953 non-null object
# dtypes: int64(3), object(20)
# memory usage: 3.3+ MB

# %%
data.head()
# Out:
#    ID Number Tipología Anf. Tipo de Provincia Rango Provincia  \
# 0      37611       DR20+BAE          Imperial  Rango ecuestre
# 1      36094       DR20+BAE          Imperial  Rango ecuestre
# 2      36095       DR20+BAE          Imperial  Rango ecuestre
# 3      36101       DR20+BAE          Imperial  Rango ecuestre
# 4      36104       DR20+BAE          Imperial  Rango ecuestre
#
#               Provincia Pais Moderno  GIS LH  Tipo de Asentamiento  \
# 0  Mauretania Tingitana           MA  -45265  Asentamiento militar
# 1  Mauretania Tingitana           MA  -45265  Asentamiento militar
# 2  Mauretania Tingitana           MA  -45265  Asentamiento militar
# 3  Mauretania Tingitana           MA  -45265  Asentamiento militar
# 4  Mauretania Tingitana           MA  -45265  Asentamiento militar
#
#   Datación Pecios                              LH       ...        \
# 0             NaN  Sidi Ali ben ahmed (Thamusida)       ...
# 1             NaN  Sidi Ali ben ahmed (Thamusida)       ...
# 2             NaN  Sidi Ali ben ahmed (Thamusida)       ...
# 3             NaN  Sidi Ali ben ahmed (Thamusida)       ...
# 4             NaN  Sidi Ali ben ahmed (Thamusida)       ...
#
#   Tipo de Campamento (1a Fase) Cronología final Campamento (Fase 1)  \
# 0                          NaN                                  NaN
# 1                          NaN                                  NaN
# 2                          NaN                                  NaN
# 3                          NaN                                  NaN
# 4                          NaN                                  NaN
#
#   Cronología inicial Campamento (Fase 2) Tipo de Campamento (2a Fase)  \
# 0                                    NaN                          NaN
# 1                                    NaN                          NaN
# 2                                    NaN                          NaN
# 3                                    NaN                          NaN
# 4                                    NaN                          NaN
#
#                                   Unidades militares Número de soldados  \
# 0  Ala I Gemelliana civium romanorum (88 p.Chr.),...       ca. 500/1000
# 1  Ala I Gemelliana civium romanorum (88 p.Chr.),...       ca. 500/1000
# 2  Ala I Gemelliana civium romanorum (88 p.Chr.),...       ca. 500/1000
# 3  Ala I Gemelliana civium romanorum (88 p.Chr.),...       ca. 500/1000
# 4  Ala I Gemelliana civium romanorum (88 p.Chr.),...       ca. 500/1000
#
#                        Tipo de Campamento   \
# 0  Campamento militar / asentamiento civil
# 1  Campamento militar / asentamiento civil
# 2  Campamento militar / asentamiento civil
# 3  Campamento militar / asentamiento civil
# 4  Campamento militar / asentamiento civil
#
#   Cronología final Campamento (Fase 2) Lugar Prod/Lugar Hallago  \
# 0                       274-278 p.Chr.                        0
# 1                       274-278 p.Chr.                        0
# 2                       274-278 p.Chr.                        0
# 3                       274-278 p.Chr.                        0
# 4                       274-278 p.Chr.                        0
#
#         Datación
# 0  150-200 p.Chr.
# 1             NaN
# 2             NaN
# 3             NaN
# 4    40-70 p.Chr.
#
# [5 rows x 23 columns]

# %%
data.Provincia.value_counts().plot(kind = 'bar')
# Out:
# Roma                            6097
# Baetica                         3929
# Germania Superior               2183
# Britannia                       1985
# Narbonensis                     1662
# Lugdunensis                      811
# Latium et Campania (Regio I)     438
# Germania Inferior                411
# Belgica                          359
# Hispania Citerior                294
# Mauretania Tingitana             288
# Raetia                           141
# Aquitania                        140
# Aegyptus                          74
# Lusitania                         18
# Pannonia Inferior                 16
# Sardinia-Corsica                  16
# Dalmatia                          15
# Pannonia Superior                 15
# Alpes Poeninae                     8
# Achaia                             6
# Etruria (Regio VII)                5
# Liguria (Regio IX)                 5
# Asia                               5
# Noricum                            4
# Venetia et Histria (Regio X)       2
# Transpadana                        2
# Alpes Cottiae                      1
# Syria                              1
# Africa Proconsularis               1
# Alpes Maritimae                    1
# Alpes Graiae                       1
# \N                                 1
# Umbria (Regio VI)                  1
# Name: Provincia, dtype: int64

# %%
# Get rid of provinces that appear less than 20 times

value_counts = data['Provincia'].value_counts() # Specific column 
to_remove = value_counts[value_counts <= 20].index
data.drop(to_remove, inplace=True)
print(data.Provincia.value_counts())
# Out:
# Roma                            6097
# Baetica                         3929
# Germania Superior               2183
# Britannia                       1985
# Narbonensis                     1662
# Lugdunensis                      811
# Latium et Campania (Regio I)     438
# Germania Inferior                411
# Belgica                          359
# Hispania Citerior                294
# Mauretania Tingitana             288
# Raetia                           141
# Aquitania                        140
# Aegyptus                          74
# Name: Provincia, dtype: int64

# %%
sns.factorplot(x = 'Tipo de Asentamiento', kind = 'count', data=data, col = 'Provincia', col_wrap=4)

# %%
df_north = data[data.Provincia.isin(['Belgica', 'Germania Superior', 'Germania Inferior', 'Britannia'])]

# %%
df_north.Provincia.value_counts()
# Out:
# Germania Superior    2183
# Britannia            1985
# Germania Inferior     411
# Belgica               359
# Name: Provincia, dtype: int64

# %%
df_north.columns
# Out:
# Index([u'ID Number', u'Tipología Anf.', u'Tipo de Provincia',
#        u'Rango Provincia', u'Provincia', u'Pais Moderno', u'GIS LH',
#        u'Tipo de Asentamiento', u'Datación Pecios', u'LH', u'LHE', u'LHE2',
#        u'Cronología inicial Campamento (Fase 1)',
#        u'Tipo de Campamento (1a Fase)',
#        u'Cronología final Campamento (Fase 1)',
#        u'Cronología inicial Campamento (Fase 2)',
#        u'Tipo de Campamento (2a Fase)', u'Unidades militares',
#        u'Número de soldados', u'Tipo de Campamento ',
#        u'Cronología final Campamento (Fase 2)', u'Lugar Prod/Lugar Hallago',
#        u'Datación '],
#       dtype='object')

# %%
df_north.plot()
